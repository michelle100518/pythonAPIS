# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
import os
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_call = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="
cities_data = []

# %%
print('Data retrieval: started\n------------------------')

rec_counter = 0
set_counter = 1

for city in cities:
    resp = req.get(api_call + city).json()
    if resp['cod'] == 200:
        print("Processing record", rec_counter % 50, "of set", set_counter, ':', city)
        cities_data.append({
            "City" : resp["name"],
            "Country" : resp["sys"]["country"],
            "Lat" : resp["coord"]["lat"],
            "Lng" : resp["coord"]["lon"],
            "Max Temp" : resp["main"]["temp_max"],
            "Humidity" : resp["main"]["humidity"],
            "Wind Speed" : resp["wind"]["speed"],
            "Cloudiness" : resp["clouds"]["all"],
            "Date" : resp["dt"]
        })
        rec_counter += 1
        if not rec_counter % 50:
            set_counter += 1
    else:
        print("City not found. Skipping:", city)
        
print('------------------------\nData retrieval: finished\n------------------------')
# Out:
# Data retrieval: started
# ------------------------
# Processing record 0 of set 1 : rikitea
# City not found. Skipping: taolanaro
# Processing record 1 of set 1 : barrow
# Processing record 2 of set 1 : hermanus
# Processing record 3 of set 1 : maunabo
# Processing record 4 of set 1 : morant bay
# Processing record 5 of set 1 : bethel
# Processing record 6 of set 1 : mataura
# Processing record 7 of set 1 : hofn
# Processing record 8 of set 1 : ostrovnoy
# Processing record 9 of set 1 : nepa nagar
# Processing record 10 of set 1 : faanui
# Processing record 11 of set 1 : vallenar
# Processing record 12 of set 1 : codrington
# City not found. Skipping: illoqqortoormiut
# Processing record 13 of set 1 : nisia floresta
# Processing record 14 of set 1 : ushuaia
# Processing record 15 of set 1 : port alfred
# Processing record 16 of set 1 : atuona
# Processing record 17 of set 1 : mar del plata
# Processing record 18 of set 1 : castro
# Processing record 19 of set 1 : rapid valley
# Processing record 20 of set 1 : carnarvon
# Processing record 21 of set 1 : qaanaaq
# Processing record 22 of set 1 : bluff
# Processing record 23 of set 1 : cidreira
# Processing record 24 of set 1 : pochutla
# Processing record 25 of set 1 : fort nelson
# Processing record 26 of set 1 : port elizabeth
# Processing record 27 of set 1 : albany
# Processing record 28 of set 1 : lagoa
# Processing record 29 of set 1 : waycross
# Processing record 30 of set 1 : chuy
# Processing record 31 of set 1 : isangel
# Processing record 32 of set 1 : rio gallegos
# Processing record 33 of set 1 : tocopilla
# Processing record 34 of set 1 : marawi
# Processing record 35 of set 1 : asyut
# Processing record 36 of set 1 : tuatapere
# Processing record 37 of set 1 : bar harbor
# Processing record 38 of set 1 : deputatskiy
# Processing record 39 of set 1 : sorland
# City not found. Skipping: barentsburg
# Processing record 40 of set 1 : ulaangom
# Processing record 41 of set 1 : cherskiy
# Processing record 42 of set 1 : sitka
# Processing record 43 of set 1 : rorvik
# Processing record 44 of set 1 : mahebourg
# Processing record 45 of set 1 : georgetown
# Processing record 46 of set 1 : ponta do sol
# Processing record 47 of set 1 : yerbogachen
# Processing record 48 of set 1 : kralendijk
# Processing record 49 of set 1 : sao filipe
# Processing record 0 of set 2 : vung tau
# Processing record 1 of set 2 : altamont
# Processing record 2 of set 2 : kapaa
# Processing record 3 of set 2 : hobart
# City not found. Skipping: toliary
# Processing record 4 of set 2 : serov
# Processing record 5 of set 2 : tiksi
# Processing record 6 of set 2 : jishou
# Processing record 7 of set 2 : hithadhoo
# Processing record 8 of set 2 : kodiak
# Processing record 9 of set 2 : puerto ayora
# City not found. Skipping: saleaula
# Processing record 10 of set 2 : tabuk
# Processing record 11 of set 2 : roald
# Processing record 12 of set 2 : yellowknife
# Processing record 13 of set 2 : aguascalientes
# Processing record 14 of set 2 : ambon
# Processing record 15 of set 2 : mehamn
# Processing record 16 of set 2 : geraldton
# Processing record 17 of set 2 : salalah
# Processing record 18 of set 2 : bathsheba
# Processing record 19 of set 2 : hambantota
# Processing record 20 of set 2 : new norfolk
# Processing record 21 of set 2 : nuqui
# Processing record 22 of set 2 : kaitangata
# Processing record 23 of set 2 : avarua
# Processing record 24 of set 2 : igrim
# Processing record 25 of set 2 : longyearbyen
# Processing record 26 of set 2 : kokstad
# Processing record 27 of set 2 : ballina
# Processing record 28 of set 2 : tomatlan
# Processing record 29 of set 2 : esperance
# Processing record 30 of set 2 : tasiilaq
# Processing record 31 of set 2 : pevek
# Processing record 32 of set 2 : bredasdorp
# Processing record 33 of set 2 : hasaki
# Processing record 34 of set 2 : broken hill
# Processing record 35 of set 2 : hit
# Processing record 36 of set 2 : eyl
# Processing record 37 of set 2 : stantsionno-oyashinskiy
# Processing record 38 of set 2 : liku
# Processing record 39 of set 2 : burshtyn
# Processing record 40 of set 2 : adet
# Processing record 41 of set 2 : gigmoto
# Processing record 42 of set 2 : touros
# Processing record 43 of set 2 : agboville
# Processing record 44 of set 2 : bilibino
# Processing record 45 of set 2 : jalu
# Processing record 46 of set 2 : luderitz
# Processing record 47 of set 2 : waddan
# Processing record 48 of set 2 : nanakuli
# Processing record 49 of set 2 : iqaluit
# Processing record 0 of set 3 : kununurra
# Processing record 1 of set 3 : vaini
# Processing record 2 of set 3 : klaksvik
# Processing record 3 of set 3 : sungairaya
# Processing record 4 of set 3 : torbay
# Processing record 5 of set 3 : akureyri
# Processing record 6 of set 3 : busselton
# Processing record 7 of set 3 : hervey bay
# City not found. Skipping: tsihombe
# Processing record 8 of set 3 : punta arenas
# Processing record 9 of set 3 : kenora
# Processing record 10 of set 3 : fairbanks
# Processing record 11 of set 3 : dicabisagan
# Processing record 12 of set 3 : hilo
# Processing record 13 of set 3 : sechura
# Processing record 14 of set 3 : havelock
# Processing record 15 of set 3 : ribeira grande
# Processing record 16 of set 3 : letlhakane
# Processing record 17 of set 3 : mogadishu
# Processing record 18 of set 3 : dunedin
# Processing record 19 of set 3 : vila franca do campo
# Processing record 20 of set 3 : manama
# City not found. Skipping: solovetskiy
# Processing record 21 of set 3 : blagodatnoye
# Processing record 22 of set 3 : saint anthony
# Processing record 23 of set 3 : gerash
# Processing record 24 of set 3 : groningen
# Processing record 25 of set 3 : udachnyy
# Processing record 26 of set 3 : cairns
# Processing record 27 of set 3 : ancud
# Processing record 28 of set 3 : saskylakh
# Processing record 29 of set 3 : sibay
# Processing record 30 of set 3 : waingapu
# Processing record 31 of set 3 : cape town
# Processing record 32 of set 3 : irece
# Processing record 33 of set 3 : jamestown
# Processing record 34 of set 3 : dikson
# City not found. Skipping: barawe
# Processing record 35 of set 3 : shingu
# Processing record 36 of set 3 : thio
# Processing record 37 of set 3 : merke
# City not found. Skipping: phan rang
# Processing record 38 of set 3 : whitehorse
# Processing record 39 of set 3 : moron
# Processing record 40 of set 3 : wilmington
# Processing record 41 of set 3 : beloha
# Processing record 42 of set 3 : lorengau
# Processing record 43 of set 3 : batouri
# Processing record 44 of set 3 : kahului
# Processing record 45 of set 3 : guerrero negro
# Processing record 46 of set 3 : olafsvik
# Processing record 47 of set 3 : lincoln
# Processing record 48 of set 3 : mosquera
# Processing record 49 of set 3 : fortuna
# Processing record 0 of set 4 : los llanos de aridane
# Processing record 1 of set 4 : bengkulu
# Processing record 2 of set 4 : sinazongwe
# Processing record 3 of set 4 : encruzilhada do sul
# Processing record 4 of set 4 : sembe
# Processing record 5 of set 4 : carta
# Processing record 6 of set 4 : tuktoyaktuk
# Processing record 7 of set 4 : carutapera
# Processing record 8 of set 4 : iralaya
# Processing record 9 of set 4 : poum
# City not found. Skipping: buon me thuot
# Processing record 10 of set 4 : gizo
# Processing record 11 of set 4 : nikolskoye
# City not found. Skipping: attawapiskat
# Processing record 12 of set 4 : faya
# City not found. Skipping: palabuhanratu
# Processing record 13 of set 4 : port lincoln
# Processing record 14 of set 4 : at-bashi
# Processing record 15 of set 4 : belaya gora
# Processing record 16 of set 4 : provideniya
# Processing record 17 of set 4 : mpulungu
# Processing record 18 of set 4 : hovd
# City not found. Skipping: louisbourg
# Processing record 19 of set 4 : masallatah
# Processing record 20 of set 4 : airai
# Processing record 21 of set 4 : alcaniz
# Processing record 22 of set 4 : khatanga
# Processing record 23 of set 4 : maldonado
# Processing record 24 of set 4 : dinhata
# Processing record 25 of set 4 : bulgan
# Processing record 26 of set 4 : barra do garcas
# Processing record 27 of set 4 : saint-philippe
# City not found. Skipping: belushya guba
# Processing record 28 of set 4 : antofagasta
# Processing record 29 of set 4 : upernavik
# Processing record 30 of set 4 : key biscayne
# Processing record 31 of set 4 : nizhniy kuranakh
# Processing record 32 of set 4 : butaritari
# Processing record 33 of set 4 : okhotsk
# Processing record 34 of set 4 : chokurdakh
# Processing record 35 of set 4 : talnakh
# Processing record 36 of set 4 : djambala
# Processing record 37 of set 4 : lokhvytsya
# Processing record 38 of set 4 : hay river
# Processing record 39 of set 4 : san patricio
# Processing record 40 of set 4 : east london
# Processing record 41 of set 4 : khanpur
# Processing record 42 of set 4 : robertsport
# Processing record 43 of set 4 : enumclaw
# Processing record 44 of set 4 : pacific grove
# Processing record 45 of set 4 : ust-koksa
# Processing record 46 of set 4 : coshocton
# Processing record 47 of set 4 : ginir
# Processing record 48 of set 4 : xuddur
# Processing record 49 of set 4 : ust-omchug
# Processing record 0 of set 5 : taupo
# Processing record 1 of set 5 : sao joao da barra
# Processing record 2 of set 5 : herat
# Processing record 3 of set 5 : cabo san lucas
# Processing record 4 of set 5 : sao joao evangelista
# Processing record 5 of set 5 : puerto baquerizo moreno
# Processing record 6 of set 5 : lompoc
# Processing record 7 of set 5 : makakilo city
# Processing record 8 of set 5 : goure
# Processing record 9 of set 5 : toguchin
# Processing record 10 of set 5 : samarai
# Processing record 11 of set 5 : dubbo
# Processing record 12 of set 5 : great falls
# Processing record 13 of set 5 : charlestown
# Processing record 14 of set 5 : flinders
# Processing record 15 of set 5 : batemans bay
# Processing record 16 of set 5 : maltahohe
# Processing record 17 of set 5 : dwarka
# Processing record 18 of set 5 : matara
# Processing record 19 of set 5 : xixiang
# Processing record 20 of set 5 : bambous virieux
# Processing record 21 of set 5 : katsuura
# Processing record 22 of set 5 : bana
# Processing record 23 of set 5 : gelemso
# Processing record 24 of set 5 : sept-iles
# Processing record 25 of set 5 : san quintin
# City not found. Skipping: amderma
# Processing record 26 of set 5 : taoudenni
# Processing record 27 of set 5 : novyy urengoy
# Processing record 28 of set 5 : yeniseysk
# City not found. Skipping: vaitupu
# City not found. Skipping: sorvag
# Processing record 29 of set 5 : narsaq
# Processing record 30 of set 5 : daru
# Processing record 31 of set 5 : de-kastri
# Processing record 32 of set 5 : oranjemund
# Processing record 33 of set 5 : ossora
# Processing record 34 of set 5 : puerto escondido
# Processing record 35 of set 5 : teknaf
# Processing record 36 of set 5 : arman
# Processing record 37 of set 5 : nerchinskiy zavod
# Processing record 38 of set 5 : vardo
# Processing record 39 of set 5 : mayumba
# Processing record 40 of set 5 : saldanha
# City not found. Skipping: sentyabrskiy
# Processing record 41 of set 5 : yar-sale
# City not found. Skipping: balykshi
# City not found. Skipping: bur gabo
# Processing record 42 of set 5 : severo-kurilsk
# Processing record 43 of set 5 : kavaratti
# Processing record 44 of set 5 : nanortalik
# Processing record 45 of set 5 : novikovo
# Processing record 46 of set 5 : am timan
# Processing record 47 of set 5 : bowen
# Processing record 48 of set 5 : arraial do cabo
# Processing record 49 of set 5 : gorontalo
# Processing record 0 of set 6 : coihaique
# Processing record 1 of set 6 : bom jardim
# Processing record 2 of set 6 : cockburn town
# Processing record 3 of set 6 : shintomi
# Processing record 4 of set 6 : de aar
# Processing record 5 of set 6 : bryan
# Processing record 6 of set 6 : bonfim
# Processing record 7 of set 6 : general roca
# Processing record 8 of set 6 : zhovkva
# Processing record 9 of set 6 : buala
# Processing record 10 of set 6 : santa barbara
# Processing record 11 of set 6 : mandawar
# City not found. Skipping: mys shmidta
# Processing record 12 of set 6 : port hedland
# Processing record 13 of set 6 : goderich
# Processing record 14 of set 6 : ascension
# Processing record 15 of set 6 : porosozero
# Processing record 16 of set 6 : lima
# Processing record 17 of set 6 : ubinskoye
# Processing record 18 of set 6 : rovaniemi
# Processing record 19 of set 6 : aklavik
# Processing record 20 of set 6 : praia
# Processing record 21 of set 6 : launceston
# Processing record 22 of set 6 : san benito
# Processing record 23 of set 6 : kaeo
# Processing record 24 of set 6 : port shepstone
# Processing record 25 of set 6 : lavrentiya
# Processing record 26 of set 6 : pangnirtung
# Processing record 27 of set 6 : buin
# Processing record 28 of set 6 : lata
# Processing record 29 of set 6 : grindavik
# Processing record 30 of set 6 : chumikan
# City not found. Skipping: nizhneyansk
# Processing record 31 of set 6 : gumia
# Processing record 32 of set 6 : hami
# Processing record 33 of set 6 : bunia
# Processing record 34 of set 6 : shahr-e babak
# Processing record 35 of set 6 : krasnoselkup
# Processing record 36 of set 6 : castrillon
# Processing record 37 of set 6 : valdivia
# Processing record 38 of set 6 : talaya
# Processing record 39 of set 6 : kurumkan
# Processing record 40 of set 6 : zhezkazgan
# Processing record 41 of set 6 : garissa
# Processing record 42 of set 6 : soissons
# Processing record 43 of set 6 : north platte
# Processing record 44 of set 6 : jiayuguan
# Processing record 45 of set 6 : kurilsk
# Processing record 46 of set 6 : kalmunai
# Processing record 47 of set 6 : alta floresta
# Processing record 48 of set 6 : galle
# Processing record 49 of set 6 : dillon
# Processing record 0 of set 7 : martapura
# Processing record 1 of set 7 : andenes
# Processing record 2 of set 7 : portgordon
# Processing record 3 of set 7 : cayenne
# Processing record 4 of set 7 : boyabat
# Processing record 5 of set 7 : neiafu
# Processing record 6 of set 7 : victoria
# Processing record 7 of set 7 : staryy nadym
# City not found. Skipping: borlange
# Processing record 8 of set 7 : merauke
# Processing record 9 of set 7 : najran
# City not found. Skipping: ondorhaan
# Processing record 10 of set 7 : meadow lake
# Processing record 11 of set 7 : lhokseumawe
# Processing record 12 of set 7 : prince rupert
# Processing record 13 of set 7 : henties bay
# Processing record 14 of set 7 : lebu
# Processing record 15 of set 7 : korla
# Processing record 16 of set 7 : san cristobal
# Processing record 17 of set 7 : alcantara
# Processing record 18 of set 7 : nsukka
# Processing record 19 of set 7 : riyadh
# Processing record 20 of set 7 : chistoye
# Processing record 21 of set 7 : baykit
# Processing record 22 of set 7 : thompson
# Processing record 23 of set 7 : umm kaddadah
# Processing record 24 of set 7 : police
# Processing record 25 of set 7 : fukue
# Processing record 26 of set 7 : harper
# Processing record 27 of set 7 : cartagena
# Processing record 28 of set 7 : muscat
# Processing record 29 of set 7 : komsomolskiy
# Processing record 30 of set 7 : portland
# Processing record 31 of set 7 : mount pleasant
# Processing record 32 of set 7 : kavarskas
# Processing record 33 of set 7 : cruzeiro do oeste
# Processing record 34 of set 7 : hilton head island
# Processing record 35 of set 7 : gat
# Processing record 36 of set 7 : calama
# Processing record 37 of set 7 : pangody
# City not found. Skipping: grand river south east
# Processing record 38 of set 7 : akom
# Processing record 39 of set 7 : coahuayana
# Processing record 40 of set 7 : baker city
# Processing record 41 of set 7 : lazaro cardenas
# Processing record 42 of set 7 : alice springs
# Processing record 43 of set 7 : valle hermoso
# Processing record 44 of set 7 : ibi
# Processing record 45 of set 7 : rancho palos verdes
# Processing record 46 of set 7 : chornoliztsi
# Processing record 47 of set 7 : harnosand
# Processing record 48 of set 7 : gonaives
# Processing record 49 of set 7 : ilebo
# Processing record 0 of set 8 : atexcatzingo
# Processing record 1 of set 8 : bolitoc
# Processing record 2 of set 8 : honiara
# Processing record 3 of set 8 : onguday
# Processing record 4 of set 8 : novo aripuana
# Processing record 5 of set 8 : kisangani
# Processing record 6 of set 8 : pozo colorado
# Processing record 7 of set 8 : tadine
# Processing record 8 of set 8 : barcelos
# Processing record 9 of set 8 : saint george
# Processing record 10 of set 8 : clyde river
# Processing record 11 of set 8 : murupara
# Processing record 12 of set 8 : kidal
# Processing record 13 of set 8 : palmas de monte alto
# Processing record 14 of set 8 : balotra
# Processing record 15 of set 8 : ilulissat
# Processing record 16 of set 8 : birin
# Processing record 17 of set 8 : ashiya
# Processing record 18 of set 8 : talara
# Processing record 19 of set 8 : tayu
# Processing record 20 of set 8 : murashi
# Processing record 21 of set 8 : sao sebastiao
# City not found. Skipping: labutta
# Processing record 22 of set 8 : sur
# Processing record 23 of set 8 : dese
# Processing record 24 of set 8 : santa maria
# Processing record 25 of set 8 : newport
# City not found. Skipping: marcona
# Processing record 26 of set 8 : mbaiki
# Processing record 27 of set 8 : isa khel
# Processing record 28 of set 8 : aseri
# Processing record 29 of set 8 : port pirie
# City not found. Skipping: umzimvubu
# Processing record 30 of set 8 : rincon
# Processing record 31 of set 8 : butia
# Processing record 32 of set 8 : koslan
# Processing record 33 of set 8 : kapoeta
# City not found. Skipping: grand centre
# Processing record 34 of set 8 : punta alta
# Processing record 35 of set 8 : kruisfontein
# City not found. Skipping: samusu
# Processing record 36 of set 8 : bilma
# Processing record 37 of set 8 : miranda
# Processing record 38 of set 8 : avera
# Processing record 39 of set 8 : trairi
# Processing record 40 of set 8 : hualmay
# Processing record 41 of set 8 : tabou
# Processing record 42 of set 8 : port blair
# Processing record 43 of set 8 : monster
# Processing record 44 of set 8 : lawang
# Processing record 45 of set 8 : placido de castro
# Processing record 46 of set 8 : matay
# Processing record 47 of set 8 : husavik
# Processing record 48 of set 8 : honningsvag
# Processing record 49 of set 8 : waverly
# Processing record 0 of set 9 : jati
# Processing record 1 of set 9 : kavieng
# Processing record 2 of set 9 : srednekolymsk
# City not found. Skipping: rolim de moura
# Processing record 3 of set 9 : yumen
# Processing record 4 of set 9 : la joya
# Processing record 5 of set 9 : rio piracicaba
# Processing record 6 of set 9 : dongsheng
# Processing record 7 of set 9 : la asuncion
# Processing record 8 of set 9 : lensk
# Processing record 9 of set 9 : ikalamavony
# Processing record 10 of set 9 : yakeshi
# City not found. Skipping: yanan
# Processing record 11 of set 9 : aranda de duero
# Processing record 12 of set 9 : atasu
# Processing record 13 of set 9 : kuragino
# Processing record 14 of set 9 : port-gentil
# Processing record 15 of set 9 : altamira
# Processing record 16 of set 9 : norman wells
# Processing record 17 of set 9 : gurjaani
# Processing record 18 of set 9 : sabang
# Processing record 19 of set 9 : kharp
# Processing record 20 of set 9 : vestmannaeyjar
# Processing record 21 of set 9 : coquimbo
# Processing record 22 of set 9 : simbahan
# Processing record 23 of set 9 : coro
# Processing record 24 of set 9 : boa vista
# City not found. Skipping: manzil tamim
# Processing record 25 of set 9 : linden
# Processing record 26 of set 9 : filotion
# Processing record 27 of set 9 : maceio
# Processing record 28 of set 9 : comodoro rivadavia
# Processing record 29 of set 9 : lakes entrance
# Processing record 30 of set 9 : fez
# Processing record 31 of set 9 : nago
# Processing record 32 of set 9 : fare
# Processing record 33 of set 9 : asau
# Processing record 34 of set 9 : xiongyue
# Processing record 35 of set 9 : victor harbor
# Processing record 36 of set 9 : laguna
# Processing record 37 of set 9 : stornoway
# Processing record 38 of set 9 : andros town
# Processing record 39 of set 9 : dingle
# City not found. Skipping: dinsor
# Processing record 40 of set 9 : cangzhou
# Processing record 41 of set 9 : san carlos de bariloche
# City not found. Skipping: bargal
# Processing record 42 of set 9 : shugurovo
# Processing record 43 of set 9 : tirumullaivasal
# Processing record 44 of set 9 : constantine
# Processing record 45 of set 9 : sidi ali
# Processing record 46 of set 9 : ayan
# Processing record 47 of set 9 : camacha
# Processing record 48 of set 9 : skeldon
# City not found. Skipping: mocambique
# Processing record 49 of set 9 : wundanyi
# Processing record 0 of set 10 : pueblo
# Processing record 1 of set 10 : kadaya
# Processing record 2 of set 10 : mount gambier
# Processing record 3 of set 10 : half moon bay
# Processing record 4 of set 10 : leningradskiy
# City not found. Skipping: viligili
# Processing record 5 of set 10 : libenge
# Processing record 6 of set 10 : bayangol
# Processing record 7 of set 10 : bolshaya rechka
# Processing record 8 of set 10 : davila
# Processing record 9 of set 10 : matamoros
# Processing record 10 of set 10 : noumea
# Processing record 11 of set 10 : dryden
# Processing record 12 of set 10 : awbari
# Processing record 13 of set 10 : deneysville
# City not found. Skipping: anar darreh
# Processing record 14 of set 10 : inuvik
# Processing record 15 of set 10 : morristown
# Processing record 16 of set 10 : gwanda
# Processing record 17 of set 10 : tongren
# Processing record 18 of set 10 : mandera
# Processing record 19 of set 10 : koyelga
# Processing record 20 of set 10 : soure
# Processing record 21 of set 10 : nhulunbuy
# Processing record 22 of set 10 : sagana
# Processing record 23 of set 10 : mackay
# Processing record 24 of set 10 : price
# Processing record 25 of set 10 : salaga
# Processing record 26 of set 10 : goundam
# City not found. Skipping: mizpe ramon
# Processing record 27 of set 10 : taltal
# Processing record 28 of set 10 : huarmey
# Processing record 29 of set 10 : pietarsaari
# Processing record 30 of set 10 : teya
# Processing record 31 of set 10 : gorin
# Processing record 32 of set 10 : tazovskiy
# Processing record 33 of set 10 : thunder bay
# Processing record 34 of set 10 : katangli
# Processing record 35 of set 10 : chenove
# Processing record 36 of set 10 : safford
# Processing record 37 of set 10 : winnemucca
# Processing record 38 of set 10 : mahanje
# Processing record 39 of set 10 : williams lake
# Processing record 40 of set 10 : namibe
# Processing record 41 of set 10 : knysna
# Processing record 42 of set 10 : chapais
# Processing record 43 of set 10 : harlingen
# Processing record 44 of set 10 : mandalgovi
# Processing record 45 of set 10 : muntilan
# Processing record 46 of set 10 : aldan
# Processing record 47 of set 10 : aasiaat
# Processing record 48 of set 10 : bonavista
# City not found. Skipping: tome-acu
# Processing record 49 of set 10 : karabash
# Processing record 0 of set 11 : la romana
# Processing record 1 of set 11 : khani
# Processing record 2 of set 11 : ardesen
# Processing record 3 of set 11 : arlit
# Processing record 4 of set 11 : ajdabiya
# Processing record 5 of set 11 : genhe
# City not found. Skipping: yomitan
# Processing record 6 of set 11 : san juan
# Processing record 7 of set 11 : harer
# Processing record 8 of set 11 : pimenta bueno
# Processing record 9 of set 11 : hamilton
# Processing record 10 of set 11 : ipixuna
# Processing record 11 of set 11 : hirado
# Processing record 12 of set 11 : sungaipenuh
# Processing record 13 of set 11 : guane
# Processing record 14 of set 11 : tateyama
# Processing record 15 of set 11 : opuwo
# Processing record 16 of set 11 : canto do buriti
# Processing record 17 of set 11 : lebedinyy
# Processing record 18 of set 11 : atar
# Processing record 19 of set 11 : batagay-alyta
# Processing record 20 of set 11 : zyryanskoye
# Processing record 21 of set 11 : takoradi
# City not found. Skipping: burica
# Processing record 22 of set 11 : sakakah
# Processing record 23 of set 11 : navirai
# Processing record 24 of set 11 : esso
# Processing record 25 of set 11 : anadyr
# Processing record 26 of set 11 : wanaka
# City not found. Skipping: tumannyy
# Processing record 27 of set 11 : salinopolis
# Processing record 28 of set 11 : juneau
# Processing record 29 of set 11 : chilliwack
# Processing record 30 of set 11 : ahipara
# Processing record 31 of set 11 : rocha
# Processing record 32 of set 11 : cedar city
# Processing record 33 of set 11 : surt
# Processing record 34 of set 11 : payo
# Processing record 35 of set 11 : astara
# Processing record 36 of set 11 : high prairie
# Processing record 37 of set 11 : brae
# Processing record 38 of set 11 : sigli
# Processing record 39 of set 11 : chimoio
# Processing record 40 of set 11 : karaj
# Processing record 41 of set 11 : sukhumi
# Processing record 42 of set 11 : walla walla
# Processing record 43 of set 11 : skvyra
# Processing record 44 of set 11 : atyrau
# Processing record 45 of set 11 : mataram
# Processing record 46 of set 11 : chancay
# Processing record 47 of set 11 : nome
# Processing record 48 of set 11 : kaifeng
# Processing record 49 of set 11 : piacabucu
# Processing record 0 of set 12 : papara
# Processing record 1 of set 12 : mayo
# Processing record 2 of set 12 : sioux lookout
# Processing record 3 of set 12 : voh
# City not found. Skipping: maloshuyka
# Processing record 4 of set 12 : rio verde de mato grosso
# Processing record 5 of set 12 : palauig
# Processing record 6 of set 12 : nam som
# City not found. Skipping: cazaje
# City not found. Skipping: sumbawa
# Processing record 7 of set 12 : mao
# Processing record 8 of set 12 : vidim
# Processing record 9 of set 12 : nenjiang
# Processing record 10 of set 12 : muros
# ------------------------
# Data retrieval: finished
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
wdf = pd.DataFrame(cities_data)
wdf
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Wind Speed  \
# 0       Rikitea      PF -23.12 -134.97     70.59        77       12.86
# 1        Barrow      US  71.29 -156.79     41.00        80       16.11
# 2      Hermanus      ZA -34.42   19.23     37.99        93        6.22
# 3       Maunabo      PR  18.01  -65.90     84.00        83        3.00
# 4    Morant Bay      JM  17.88  -76.41     84.20        74        3.36
# ..          ...     ...    ...     ...       ...       ...         ...
# 556     Nam Som      TH  17.77  102.19     80.60        88        4.70
# 557       Mahon      ES  39.89    4.27     73.40        94        4.70
# 558       Vidim      RU  56.41  103.11     64.29        37        7.78
# 559      Mergen      CN  49.18  125.22     63.91        94       11.56
# 560       Muros      ES  42.78   -9.06     68.00        93        9.17
#
#      Cloudiness        Date
# 0             4  1597637305
# 1            90  1597637306
# 2           100  1597637306
# 3             3  1597637306
# 4            75  1597637043
# ..          ...         ...
# 556          90  1597637468
# 557           1  1597637469
# 558          17  1597637469
# 559         100  1597637359
# 560          75  1597637447
#
# [561 rows x 9 columns]

# %%
if not os.path.exists("./output_data/"):
    os.mkdir("./output_data/")
wdf.to_csv("./output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
wdf.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Wind Speed  Cloudiness  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    19.774135   16.495205   67.781230   70.549020    7.339804   48.759358
# std     33.709002   91.797071   14.616666   20.531113    5.077102   38.081128
# min    -54.800000 -175.200000   31.960000    3.000000    0.430000    0.000000
# 25%     -7.840000  -67.580000   57.180000   59.000000    3.780000    7.000000
# 50%     22.890000   20.280000   68.050000   75.000000    5.910000   44.000000
# 75%     49.170000   97.150000   79.390000   86.000000    9.840000   88.000000
# max     78.220000  178.420000  104.000000  100.000000   33.330000  100.000000
#
#                Date
# count  5.610000e+02
# mean   1.597637e+09
# std    8.628543e+01
# min    1.597637e+09
# 25%    1.597637e+09
# 50%    1.597637e+09
# 75%    1.597637e+09
# max    1.597637e+09

# %%
#  Get the indices of cities that have humidity over 100%.
indexes = wdf[wdf.Humidity > 100].index
indexes
# Out:
# Int64Index([], dtype='int64')

# %%
wdf_clean = wdf[wdf.Humidity <= 100]
wdf_clean
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Wind Speed  \
# 0       Rikitea      PF -23.12 -134.97     70.59        77       12.86
# 1        Barrow      US  71.29 -156.79     41.00        80       16.11
# 2      Hermanus      ZA -34.42   19.23     37.99        93        6.22
# 3       Maunabo      PR  18.01  -65.90     84.00        83        3.00
# 4    Morant Bay      JM  17.88  -76.41     84.20        74        3.36
# ..          ...     ...    ...     ...       ...       ...         ...
# 556     Nam Som      TH  17.77  102.19     80.60        88        4.70
# 557       Mahon      ES  39.89    4.27     73.40        94        4.70
# 558       Vidim      RU  56.41  103.11     64.29        37        7.78
# 559      Mergen      CN  49.18  125.22     63.91        94       11.56
# 560       Muros      ES  42.78   -9.06     68.00        93        9.17
#
#      Cloudiness        Date
# 0             4  1597637305
# 1            90  1597637306
# 2           100  1597637306
# 3             3  1597637306
# 4            75  1597637043
# ..          ...         ...
# 556          90  1597637468
# 557           1  1597637469
# 558          17  1597637469
# 559         100  1597637359
# 560          75  1597637447
#
# [561 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
north = wdf_clean[wdf_clean["Lat"] > 0]
south = wdf_clean[wdf_clean["Lat"] < 0]

# %%
plt.title("City Latitude vs Max Temperature as of August 16th, 2020 (Both hemispheres)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(wdf_clean["Lat"],
           wdf_clean["Max Temp"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Max Temperature as of August 16th, 2020 (Southern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(south["Lat"],
           south["Max Temp"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Max Temperature as of August 16th, 2020 (Northern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(north["Lat"],
           north["Max Temp"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %% [markdown]
# ### Observations:
# - Note: it's currently summer in the Northern Hemisphere.
# - The data seems to form an almost perfect parabola. This gives us a pretty good idea of how weather probably behaves on both hemispheres.
# - The Northern Hemisphere is visibly a little hotter in this plot. That makes sense, since it's summer.
# - Even if the Northern Hemisphere is in summer season at the moment, the Southern Hemisphere shows a similar behavior during its winter season.
# - A safe bet would be to assume that summers are hotter in the Southern Hemisphere than in the Northern Hemisphere, since Southern winter is visibly similar to Northern summer, even when they're opposite seasons.
# - Weather around the Equator should stay basically the same throughout the whole year.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.title("City Latitude vs Humidity as of August 16th, 2020")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(wdf["Lat"],
           wdf["Humidity"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Humidity as of August 16th, 2020 (Southern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(south["Lat"],
           south["Humidity"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Humidity as of August 16th, 2020 (Northern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(north["Lat"],
           north["Humidity"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %% [markdown]
# ### Observations:
# - Note: it's currently summer in the Northern Hemisphere.
# - This plot shows no immediate correlation between latitude and humidity,
# - That being said, it does at least appear that there is one observation worth mentioning: several cities near both tropics (Cancer and Capricorn) seem to have lower humidity, maybe due to how directly the sun hits those regions.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.title("City Latitude vs Cloudiness as of August 16th, 2020")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(wdf["Lat"],
           wdf["Cloudiness"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Cloudiness as of August 16th, 2020 (Southern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(south["Lat"],
           south["Cloudiness"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Cloudiness as of August 16th, 2020 (Northern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(north["Lat"],
           north["Cloudiness"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %% [markdown]
# ### Observations:
# - Note: it's currently summer in the Northern Hemisphere.
# - The plots show no obvious sign of correlation between latitude and cloudiness, except for the following observation:
#     - Cities near the equator are less prone to clear skies.
# - One would think the south has less clouds than the north. However, this can be easily explained by the simple fact that there are more cities from the north than the south in this random dataset.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.title("City Latitude vs Wind Speed as of August 16th, 2020")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(wdf["Lat"],
           wdf["Wind Speed"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Wind Speed as of August 16th, 2020 (Southern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(south["Lat"],
           south["Wind Speed"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %%
plt.title("City Latitude vs Wind Speed as of August 16th, 2020 (Northern hempisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(linestyle = '-', linewidth = 1, alpha = 0.25)

plt.scatter(north["Lat"],
           north["Wind Speed"],
           facecolor = "steelblue",
           edgecolor = "blue")
plt.show()

# %% [markdown]
# ### Observations:
# - Note: it's currently summer in the Northern Hemisphere.
# - The plots show a slight, but obvious correlation between latitude and wind speed.
# - The polar regions seem to have overall higher wind speeds.
# - The area near the tropic of Cancer seems to have higher wind speeds than average, but that's normal, since hurricane season is approaching.

# %% [markdown]
# ## Linear Regression

# %%
import scipy.stats

# %%
def linearRegression(x, y):
    correlation_matrix = np.corrcoef(x, y)
    correlation_xy = correlation_matrix[0, 1]
    print("The value of r-squared is", correlation_xy ** 2)
    m, b, _, _, _ = stats.linregress(x, y)
    eq = "y = " + str(round(m, 3)) + "x + " + str(round(b, 3))
    plt.scatter(x, y)
    regression = x * m + b
    plt.plot(x, regression, "g-")
    plt.legend(labels = eq, loc = "best")
# Out:
# 0.4663909706455749
# 0.5549480264051715

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title("Latitude vs Max Temp Linear Regression (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (Fahrenheit)")
linearRegression(north["Lat"], north["Max Temp"])
# Out:
# The r-squared is: 0.8271188905041935

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.39936284758885965

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10829462153873139

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0008996079328825663

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.05768812657005063

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.0684912094859049

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.023371104533850804

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.03381889207758188
